# %%
import cv2
import numpy as np
from imutils import contours

# from pytesseract import pytesseract
# pytesseract.tesseract_cmd = "C:\\Users\\HP\\AppData\\Local\\Tesseract-OCR\\tesseract.exe"

# %%
img = cv2.imread("np2.jpg")

grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# grey_img = cv2.bilateralFilter(grey_img,11,17,17)
# _,thresh = cv2.threshold(grey_img,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
canny_edge = cv2.Canny(grey_img,170,200)
contours,hierarchy = cv2.findContours(canny_edge.copy(),cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# contours,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
contours = sorted(contours,key = cv2.contourArea, reverse=True)[:30]

licensePlate = None

for cnt in contours:
    peri = cv2.arcLength(cnt,True)
    poly = cv2.approxPolyDP(cnt,0.01 * peri, True)
    if len(poly) == 4:   # if it is a rect
        x,y,w,h = cv2.boundingRect(cnt)
        licensePlate = grey_img[y:y+h,x:x+w]
        break

cv2.imshow("image",licensePlate)

# # licensePlate = cv2.resize(licensePlate, (300, 50)) 
# _,thresh = cv2.threshold(licensePlate,0,255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
# # canny_edge = cv2.Canny(licensePlate,170,240)
# cnts,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# (cnts, _) = contours.sort_contours(cnts, method="left-to-right")
# roiNum = 0
# mask = np.zeros(licensePlate.shape, dtype=np.uint8)
# # mask = np.full(licensePlate.shape,255, dtype=np.uint8)
# cv2.imshow('thresh', thresh)
# for c in cnts:
#     area = cv2.contourArea(c)
#     if area < 1000 and area > 100:
#         x,y,w,h = cv2.boundingRect(c)
#         # ROI = thresh[y:y+h, x:x+w]
#         ROI = 255 - thresh[y:y+h, x:x+w]
#         cv2.drawContours(mask, [c], -1, (255,255,255), -1)
#         # cv2.imshow('ROI_{}.png'.format(roiNum), ROI)
#         roiNum += 1
        
# cv2.imshow('mask', mask)


cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\ML-and-DP-practice\Machine and Deep Learning\Practice\NumberPlateDetection\NumberPlateDetector.ipynb Cell 2 in <cell line: 27>()
#      <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000006?line=24'>25</a> # canny_edge = cv2.Canny(licensePlate,170,240)
#      <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000006?line=25'>26</a> cnts,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# ---> <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000006?line=26'>27</a> (cnts, _) = contours.sort_contours(cnts, method="left-to-right")
#      <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000006?line=27'>28</a> roiNum = 0
#      <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000006?line=28'>29</a> mask = np.zeros(licensePlate.shape, dtype=np.uint8)
#
# AttributeError: 'list' object has no attribute 'sort_contours'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
img = cv2.imread("np2.jpg")
grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# grey_img = cv2.bilateralFilter(grey_img,11,17,17)
# _,thresh = cv2.threshold(grey_img,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
canny_edge = cv2.Canny(grey_img,170,200)
cnts,hierarchy = cv2.findContours(canny_edge,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# contours,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
cnts = sorted(cnts,key = cv2.contourArea, reverse=True)[:30]

# contour_with_plate = None
licensePlate = None

for cnt in cnts:
    # getting perimeter of contour
    peri = cv2.arcLength(cnt,True)
    # getting the polygon details that contour is
    poly = cv2.approxPolyDP(cnt,0.1 * peri, True)
    if len(poly) == 4:   # if it is a rect
        # contour_with_plate = poly
        x,y,w,h = cv2.boundingRect(cnt)
        licensePlate = grey_img[y:y+h,x:x+w]
        break

cv2.imshow("img",licensePlate)
# licensePlate = cv2.resize(licensePlate, (300, 50)) 
_,thresh = cv2.threshold(licensePlate,0,255, cv2.THRESH_OTSU)
# canny_edge = cv2.Canny(licensePlate,170,240)
cnts,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
(cnts, _) = contours.sort_contours(cnts, method="left-to-right")
roiNum = 0
mask = np.zeros(licensePlate.shape, dtype=np.uint8)
# mask = np.full(licensePlate.shape,255, dtype=np.uint8)
cv2.imshow('thresh', thresh)
for c in cnts:
    area = cv2.contourArea(c)
    if area < 1000 and area > 100:
        x,y,w,h = cv2.boundingRect(c)
        # ROI = thresh[y:y+h, x:x+w]
        ROI = 255 - thresh[y:y+h, x:x+w]
        cv2.drawContours(mask, [c], -1, (255,255,255), -1)
        # cv2.imshow('ROI_{}.png'.format(roiNum), ROI)
        roiNum += 1
        
cv2.imshow('mask', mask)
# cv2.imshow('thresh', thresh)
# licensePlate = cv2.bilateralFilter(licensePlate,11,17,17)
# hgt , wdt  = licensePlate.shape
# _,thresh = cv2.threshold(licensePlate,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
# text = pytesseract.image_to_string(licensePlate)
# boxes = pytesseract.image_to_boxes(licensePlate)

# for box in boxes.splitlines():
#     box = box.split()
#     x,y,w,h = int(box[1]), int(box[2]), int(box[3]), int(box[4])
#     cv2.rectangle(licensePlate,(x,hgt-y),(w,hgt-h), (0,0,255), 1)
#     cv2.putText(licensePlate,box[0],(x,hgt-h), cv2.FONT_HERSHEY_COMPLEX,0.5,(0,255,0),2)
    
    
# print(text)
cv2.imshow("image",licensePlate)
cv2.waitKey()
cv2.destroyAllWindows()

# if cv2.waitKey(0) & 0XFF==ord('q'):
#     cv2.destroyAllWindows()
# else:
#     cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from imutils import contours

img = cv2.imread('np2.jpg')

grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# grey_img = cv2.bilateralFilter(grey_img,11,17,17)
_,thresh = cv2.threshold(grey_img,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
# canny_edge = cv2.Canny(grey_img,170,200)
# contours,hierarchy = cv2.findContours(canny_edge.copy(),cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
contours,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
contours = sorted(contours,key = cv2.contourArea, reverse=True)[:30]

licensePlate = None

for cnt in contours:
    peri = cv2.arcLength(cnt,True)
    poly = cv2.approxPolyDP(cnt,0.1 * peri, True)
    if len(poly) == 4:   # if it is a rect
        x,y,w,h = cv2.boundingRect(cnt)
        licensePlate = grey_img[y:y+h,x:x+w]
        break
# licensePlate = cv2.bilateralFilter(licensePlate,11,17,17)
cv2.imshow("image",img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\ML-and-DP-practice\Machine and Deep Learning\Practice\NumberPlateDetection\NumberPlateDetector.ipynb Cell 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000003?line=0'>1</a> import cv2
#       <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000003?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000003?line=2'>3</a> from imutils import contours
#       <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000003?line=4'>5</a> img = cv2.imread('np2.jpg')
#       <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000003?line=6'>7</a> grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\imutils\__init__.py:8, in <module>
#       5 __version__ = "0.5.4"
#       7 # import the necessary packages
# ----> 8 from .convenience import translate
#       9 from .convenience import rotate
#      10 from .convenience import rotate_bound
#
# File ~\AppData\Roaming\Python\Python39\site-packages\imutils\convenience.py:65, in <module>
#      62     # perform the actual rotation and return the image
#      63     return cv2.warpAffine(image, M, (nW, nH))
# ---> 65 def resize(image, width=None, height=None, inter=cv2.INTER_AREA):
#      66     # initialize the dimensions of the image to be resized and
#      67     # grab the image size
#      68     dim = None
#      69     (h, w) = image.shape[:2]
#
# AttributeError: module 'cv2' has no attribute 'INTER_AREA'

# %%
import cv2
import numpy as np
from imutils import contours

image = cv2.imread('np3.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_,thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

cnts = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
(cnts, _) = contours.sort_contours(cnts, method="left-to-right")
mask = np.zeros(image.shape, dtype=np.uint8)
ROI_number = 0
# cv2.imshow('mask1', mask)
for c in cnts:
    area = cv2.contourArea(c)
    if area < 1000 and area > 100:
        x,y,w,h = cv2.boundingRect(c)
        ROI = 255 - thresh[y:y+h, x:x+w]
        cv2.drawContours(mask, [c], -1, (255,255,255), -1)
        cv2.imshow('ROI_{}.png'.format(ROI_number), ROI)
        ROI_number += 1

cv2.imshow('mask', mask)
cv2.imshow('thresh', thresh)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\ML-and-DP-practice\Machine and Deep Learning\Practice\NumberPlateDetection\NumberPlateDetector.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000004?line=0'>1</a> import cv2
#       <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000004?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000004?line=2'>3</a> from imutils import contours
#       <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000004?line=4'>5</a> image = cv2.imread('np3.jpg')
#       <a href='vscode-notebook-cell:/d%3A/ML-and-DP-practice/Machine%20and%20Deep%20Learning/Practice/NumberPlateDetection/NumberPlateDetector.ipynb#ch0000004?line=5'>6</a> gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\imutils\__init__.py:8, in <module>
#       5 __version__ = "0.5.4"
#       7 # import the necessary packages
# ----> 8 from .convenience import translate
#       9 from .convenience import rotate
#      10 from .convenience import rotate_bound
#
# File ~\AppData\Roaming\Python\Python39\site-packages\imutils\convenience.py:65, in <module>
#      62     # perform the actual rotation and return the image
#      63     return cv2.warpAffine(image, M, (nW, nH))
# ---> 65 def resize(image, width=None, height=None, inter=cv2.INTER_AREA):
#      66     # initialize the dimensions of the image to be resized and
#      67     # grab the image size
#      68     dim = None
#      69     (h, w) = image.shape[:2]
#
# AttributeError: module 'cv2' has no attribute 'INTER_AREA'

# %%
import cv2
import numpy as np
from imutils import contours

img = cv2.imread('np3.jpg')

grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# grey_img = cv2.bilateralFilter(grey_img,11,17,17)
# _,thresh = cv2.threshold(grey_img,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
canny_edge = cv2.Canny(grey_img,170,200)
cnts,hierarchy = cv2.findContours(canny_edge,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# contours,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
cnts = sorted(cnts,key = cv2.contourArea, reverse=True)[:30]

# contour_with_plate = None
licensePlate = None

for cnt in cnts:
    # getting perimeter of contour
    peri = cv2.arcLength(cnt,True)
    # getting the polygon details that contour is
    poly = cv2.approxPolyDP(cnt,0.1 * peri, True)
    if len(poly) == 4:   # if it is a rect
        # contour_with_plate = poly
        x,y,w,h = cv2.boundingRect(cnt)
        licensePlate = grey_img[y:y+h,x:x+w]
        break

# licensePlate = cv2.resize(licensePlate, (300, 50)) 
_,thresh = cv2.threshold(licensePlate,0,255, cv2.THRESH_OTSU)
# canny_edge = cv2.Canny(licensePlate,170,240)
cnts,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
(cnts, _) = contours.sort_contours(cnts, method="left-to-right")
ROI_number = 0
mask = np.zeros(licensePlate.shape, dtype=np.uint8)
# mask = np.full(licensePlate.shape,255, dtype=np.uint8)
cv2.imshow('thresh', thresh)
for c in cnts:
    area = cv2.contourArea(c)
    if area < 1000 and area > 100:
        x,y,w,h = cv2.boundingRect(c)
        ROI = thresh[y:y+h, x:x+w]
        # ROI = 255 - thresh[y:y+h, x:x+w]
        cv2.drawContours(mask, [c], -1, (255,255,255), -1)
        cv2.imshow('ROI_{}.png'.format(ROI_number), ROI)
        ROI_number += 1
        
cv2.imshow('mask', mask)
# cv2.imshow('thresh', thresh)
licensePlate = cv2.bilateralFilter(licensePlate,11,17,17)
# hgt , wdt  = licensePlate.shape
# _,thresh = cv2.threshold(licensePlate,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
# text = pytesseract.image_to_string(licensePlate)
# boxes = pytesseract.image_to_boxes(licensePlate)

# for box in boxes.splitlines():
#     box = box.split()
#     x,y,w,h = int(box[1]), int(box[2]), int(box[3]), int(box[4])
#     cv2.rectangle(licensePlate,(x,hgt-y),(w,hgt-h), (0,0,255), 1)
#     cv2.putText(licensePlate,box[0],(x,hgt-h), cv2.FONT_HERSHEY_COMPLEX,0.5,(0,255,0),2)
    
    
# print(text)
cv2.imshow("image",licensePlate)
if cv2.waitKey(0) & 0XFF==ord('q'):
    cv2.destroyAllWindows()
else:
    cv2.destroyAllWindows()
