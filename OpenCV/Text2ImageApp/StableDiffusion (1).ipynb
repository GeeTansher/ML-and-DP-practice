# %%
pip install transformers diffusers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 62.8/62.8 kB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 267.7/267.7 kB 2.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 151.6/151.6 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.5/78.5 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.5/61.5 kB 3.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 140.4/140.4 kB 2.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 161.1/161.1 kB 10.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\vrgpv\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
from PIL import ImageTk
# from google.colab.patches import cv2_imshow
import cv2
import torch
# from torch import autocast
from diffusers import StableDiffusionPipeline
import numpy as np

# %%
auth_token = "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"

# %%
modelid = "CompVis/stable-diffusion-v1-4"
# device = "cuda"
# device = "OpenCL"
# pipe = StableDiffusionPipeline.from_pretrained(modelid, revision="fp16", torch_dtype=torch.float16, use_auth_token=auth_token)
# pipe.to(device)
pipe = StableDiffusionPipeline.from_pretrained(modelid, use_auth_token=auth_token)
del pipe.vae.encoder
# Out:
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# C:\Users\vrgpv\AppData\Roaming\Python\Python39\site-packages\huggingface_hub\file_download.py:123: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\vrgpv\.cache\huggingface\diffusers. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# ...

# %%
prompt = "Alien with a pink hat riding a horse with wings of fire, 4K."

# %%
def generate(prompt):
    # with autocast(device):
    #     image = pipe(prompt, guidance_scale=9.5)["sample"][0]
    image = pipe(prompt, guidance_scale=9.5)["sample"][0]

    return image

# %%
image = generate(prompt)
# Out:
# 100%|██████████| 51/51 [7:40:42<00:00, 542.00s/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 image = generate(prompt)
#
# Cell In [5], line 4, in generate(prompt)
#       1 def generate(prompt):
#       2     # with autocast(device):
#       3     #     image = pipe(prompt, guidance_scale=9.5)["sample"][0]
# ----> 4     image = pipe(prompt, guidance_scale=9.5)["sample"][0]
#       6     return image
#
# File ~\AppData\Roaming\Python\Python39\site-packages\diffusers\utils\outputs.py:88, in BaseOutput.__getitem__(self, k)
#      86 if isinstance(k, str):
#      87     inner_dict = {k: v for (k, v) in self.items()}
# ---> 88     return inner_dict[k]
#      89 else:
#      90     return self.to_tuple()[k]
#
# KeyError: 'sample'

# %%
img = np.array(image)
# cv2_imshow(img)
cv2.imshow(img)
cv2.waitKey()
cv2.destroyAllWindows()
